# %%
import numpy as np
import pandas as pd
from rdflib import Namespace, Graph, RDFS
from rdflib.term import URIRef, Literal

# %%
# prefixes used in the graph
WD = Namespace('http://www.wikidata.org/entity/')
WDT = Namespace('http://www.wikidata.org/prop/direct/')
SCHEMA = Namespace('http://schema.org/')
DDIS = Namespace('http://ddis.ch/atai/')
QUERY_PREFIX = \
"""PREFIX ddis: <http://ddis.ch/atai/> 
PREFIX wd: <http://www.wikidata.org/entity/> 
PREFIX wdt: <http://www.wikidata.org/prop/direct/> 
PREFIX schema: <http://schema.org/>
"""

# %%
graph = Graph()
graph.parse('../data/14_graph.nt', format='turtle')
# Out:
# <Graph identifier=Nf99cf939f7594f8491a04c6b62c036d5 (<class 'rdflib.graph.Graph'>)>

# %%
uri2lbl = {uri: str(lbl) for uri, lbl in graph.subject_objects(RDFS.label)}
print(f"Number of uris: {len(uri2lbl)}")
print(f"Example: {dict(list(uri2lbl.items())[:5])}")
# Out:
# Number of uris: 158059
# Example: {rdflib.term.URIRef('http://schema.org/description'): 'node description', rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'): 'node label', rdflib.term.URIRef('http://www.wikidata.org/entity/P1258'): 'Rotten Tomatoes ID', rdflib.term.URIRef('http://www.wikidata.org/entity/P161'): 'cast member', rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P161'): 'cast member'}

# %%
df_uri = pd.DataFrame(list(uri2lbl.items()), columns=['uri', 'label'])
df_uri
# Out:
#                                                uri                     label
# 0                    http://schema.org/description          node description
# 1       http://www.w3.org/2000/01/rdf-schema#label                node label
# 2             http://www.wikidata.org/entity/P1258        Rotten Tomatoes ID
# 3              http://www.wikidata.org/entity/P161               cast member
# 4         http://www.wikidata.org/prop/direct/P161               cast member
# ...                                            ...                       ...
# 158054      http://www.wikidata.org/entity/Q723685           video on demand
# 158055       http://www.wikidata.org/entity/Q11424                      film
# 158056        http://www.wikidata.org/entity/Q1860                   English
# 158057          http://www.wikidata.org/entity/Q30  United States of America
# 158058       http://www.wikidata.org/entity/Q33999                     actor
#
# [158059 rows x 2 columns]

# %% [markdown]
# Prepare predicates

# %%
predicates = set(graph.predicates())
df_rel = df_uri[df_uri['uri'].isin(predicates)].reset_index(drop=True)
df_rel
# Out:
#                                             uri                          label
# 0                 http://schema.org/description               node description
# 1    http://www.w3.org/2000/01/rdf-schema#label                     node label
# 2      http://www.wikidata.org/prop/direct/P161                    cast member
# 3     http://www.wikidata.org/prop/direct/P1657               MPAA film rating
# 4     http://www.wikidata.org/prop/direct/P1981                FSK film rating
# ..                                          ...                            ...
# 248    http://www.wikidata.org/prop/direct/P931  place served by transport hub
# 249    http://www.wikidata.org/prop/direct/P937                  work location
# 250    http://www.wikidata.org/prop/direct/P941                    inspired by
# 251    http://www.wikidata.org/prop/direct/P945                     allegiance
# 252     http://www.wikidata.org/prop/direct/P97                    noble title
#
# [253 rows x 2 columns]

# %%
df_rel['label'].duplicated().sum()
# Out:
# 0

# %%
df_rel[df_rel['uri'].apply(lambda x: x.split('/')[-1][0]!='P')]
# Out:
#                                           uri             label
# 0               http://schema.org/description  node description
# 1  http://www.w3.org/2000/01/rdf-schema#label        node label

# %% [markdown]
# Entity

# %%
entities = set(graph.subjects()) | {s for s in graph.objects() if isinstance(s,URIRef)}

# %%
df_ent = df_uri[df_uri['uri'].isin(entities)].reset_index(drop=True)
df_ent
# Out:
#                                                uri                     label
# 0                    http://schema.org/description          node description
# 1       http://www.w3.org/2000/01/rdf-schema#label                node label
# 2             http://www.wikidata.org/entity/P1258        Rotten Tomatoes ID
# 3              http://www.wikidata.org/entity/P161               cast member
# 4         http://www.wikidata.org/prop/direct/P161               cast member
# ...                                            ...                       ...
# 158054      http://www.wikidata.org/entity/Q723685           video on demand
# 158055       http://www.wikidata.org/entity/Q11424                      film
# 158056        http://www.wikidata.org/entity/Q1860                   English
# 158057          http://www.wikidata.org/entity/Q30  United States of America
# 158058       http://www.wikidata.org/entity/Q33999                     actor
#
# [158059 rows x 2 columns]

# %%
df_ent[df_ent['uri'].apply(lambda x: x.split('/')[-1][0]!='Q')]
# Out:
#                                               uri  \
# 0                   http://schema.org/description
# 1      http://www.w3.org/2000/01/rdf-schema#label
# 2            http://www.wikidata.org/entity/P1258
# 3             http://www.wikidata.org/entity/P161
# 4        http://www.wikidata.org/prop/direct/P161
# ...                                           ...
# 24867    http://www.wikidata.org/prop/direct/P931
# 24868    http://www.wikidata.org/prop/direct/P937
# 24869    http://www.wikidata.org/prop/direct/P941
# 24870    http://www.wikidata.org/prop/direct/P945
# 24871     http://www.wikidata.org/prop/direct/P97
#
#                                label
# 0                   node description
# 1                         node label
# 2                 Rotten Tomatoes ID
# 3                        cast member
# 4                        cast member
# ...                              ...
# 24867  place served by transport hub
# 24868                  work location
# 24869                    inspired by
# 24870                     allegiance
# 24871                    noble title
#
# [300 rows x 2 columns]

# %%
df_ent = df_ent[df_ent['uri'].apply(lambda x: x.split('/')[-1][0]=='Q')].reset_index(drop=True)

# %%
df_uri.to_pickle('../data/df_uri.pkl')
df_rel.to_pickle('../data/df_rel.pkl')
df_ent.to_pickle('../data/df_ent.pkl')
df_rel['label'].to_csv('../data/relations.txt', index=False, header=False)

# %% [markdown]
# People

# %%
PERSON_QUERY = QUERY_PREFIX + \
""" 
SELECT ?person ?lbl WHERE {
# ?person wdt:P31 wd:Q5 .
# ?person rdfs:label ?lbl .
}
"""

person_res = graph.query(PERSON_QUERY)

# %%
df_person = pd.DataFrame(person_res, columns=['uri', 'label'])
df_person
# Out:
#                                               uri             label
# 0       http://www.wikidata.org/entity/Q100423423    Viktor Krištof
# 1         http://www.wikidata.org/entity/Q1012658         Yuji Nomi
# 2         http://www.wikidata.org/entity/Q1019375  Béatrice Thiriet
# 3       http://www.wikidata.org/entity/Q102290694     Oleg Kapanets
# 4       http://www.wikidata.org/entity/Q102443065           Ram Lee
# ...                                           ...               ...
# 100152      http://www.wikidata.org/entity/Q44442  Dan Castellaneta
# 100153      http://www.wikidata.org/entity/Q39829      Stephen King
# 100154     http://www.wikidata.org/entity/Q296577      Frank Welker
# 100155      http://www.wikidata.org/entity/Q25089       Woody Allen
# 100156      http://www.wikidata.org/entity/Q42869      Nicolas Cage
#
# [100157 rows x 2 columns]

# %%
MOVIE_QUERY = QUERY_PREFIX + \
"""
SELECT ?movie ?lbl WHERE {
# ?movie wdt:P31 wd:Q11424 .
# ?movie rdfs:label ?lbl .
}
"""

movie_res = graph.query(MOVIE_QUERY)

# %%
df_movie = pd.DataFrame(movie_res, columns=['uri', 'label'])
df_movie
# Out:
#                                              uri  \
# 0        http://www.wikidata.org/entity/Q1000825
# 1        http://www.wikidata.org/entity/Q1001777
# 2        http://www.wikidata.org/entity/Q1001943
# 3      http://www.wikidata.org/entity/Q100232971
# 4        http://www.wikidata.org/entity/Q1002480
# ...                                          ...
# 24379   http://www.wikidata.org/entity/Q23010088
# 24380      http://www.wikidata.org/entity/Q17738
# 24381   http://www.wikidata.org/entity/Q23781155
# 24382   http://www.wikidata.org/entity/Q19590955
# 24383   http://www.wikidata.org/entity/Q77855044
#
#                                                    label
# 0                                               Jan Dara
# 1                                         Moondram Pirai
# 2      Buffalo Bill and the Indians, or Sitting Bull'...
# 3                                         What We Wanted
# 4                                  Wanted: Dead or Alive
# ...                                                  ...
# 24379                             Spider-Man: Homecoming
# 24380                 Star Wars: Episode IV – A New Hope
# 24381                                  Avengers: Endgame
# 24382                                          Rogue One
# 24383                                    Women Make Film
#
# [24384 rows x 2 columns]

# %%
GENRE_QUERY = QUERY_PREFIX + \
"""
SELECT ?genre ?lbl WHERE {
# ?genre wdt:P31 wd:Q201658 .
# ?genre rdfs:label ?lbl .
}
"""
genre_res = graph.query(GENRE_QUERY)

# %%
df_genre = pd.DataFrame(genre_res, columns=['uri', 'label'])
df_genre
# Out:
#                                           uri              label
# 0     http://www.wikidata.org/entity/Q1108032         Mumblecore
# 1    http://www.wikidata.org/entity/Q11298267      gambling film
# 2     http://www.wikidata.org/entity/Q1190502  surrealist cinema
# 3     http://www.wikidata.org/entity/Q1740789     poliziotteschi
# 4    http://www.wikidata.org/entity/Q21858363   psychedelic film
# ..                                        ...                ...
# 208   http://www.wikidata.org/entity/Q2484376      thriller film
# 209    http://www.wikidata.org/entity/Q200092        horror film
# 210    http://www.wikidata.org/entity/Q188473        action film
# 211    http://www.wikidata.org/entity/Q157443        comedy film
# 212    http://www.wikidata.org/entity/Q130232              drama
#
# [213 rows x 2 columns]

# %%
df_person.to_pickle('../data/df_person.pkl')
df_movie.to_pickle('../data/df_movie.pkl')
df_genre.to_pickle('../data/df_genre.pkl')

# %%
df_ent['label'].tolist()
# Out:
# ['Jan Dara',
#  'Elektra – Original Motion Picture Score',
#  'Moondram Pirai',
#  "Buffalo Bill and the Indians, or Sitting Bull's History Lesson",
#  'Buffalo Girls',
#  'Buffalo Girls',
#  "Buffalo '66",
#  'What We Wanted',
#  'Anti-Technodrome gear',
#  'Wanted: Dead or Alive',
#  'Portable Portal Generator',
#  'Linger',
#  'Eastern Condors',
#  "Jay's Pizza",
#  'Amerika',
#  'Amerika',
#  "Baxter Stockman's teleporter",
#  'Sergeant Garcia',
#  'Trans Latin American',
#  'Bukowski: Born into This',
#  'Furiosa',
#  'Fatal Move',
#  'On the Mountain of Tai Hang',
#  'Viktor Krištof',
#  'Forever Enthralled',
#  'Bulletproof',
#  'Bulletproof',
#  'Kill the Irishman',
#  'Bullseye!',
#  'Bully',
#  'Bully',
#  'Dry Wind',
#  'The Big Hit',
#  'The Big Hit',
#  'Angels Fallen',
#  'Gagarine',
#  'Golimaar',
#  'O Maidens in Your Savage Season',
#  'Adhurs',
#  'Rose Island',
#  'Bunny',
#  'Simha',
#  'Rakta Charitra',
#  'Khaleja',
#  'Igor Hnízdo',
#  'Jimmy Malone',
#  'John Patrick Mason',
#  'Ginko',
#  'Pilar Estravados',
#  'Princess Natalia Dragomiroff',
#  'Hildegarde Schmidt',
#  'Biniamino Marquez',
#  'Robert MacDougal',
#  'Peacemaker',
#  'Christmas Made to Order',
#  'My Christmas Inn',
#  'Sleeper',
#  'Sleeper',
#  'Sleeper',
#  'Separated at Birth',
#  'Christmas Land',
#  'Gorillas in the Mist',
#  'Gorillas in the Mist',
#  'Operation Christmas Drop',
#  'Fred Flintstone',
#  'Yuji Nomi',
#  'Jasmine Women',
#  'Sunstreaker',
#  'Blind Mountain',
#  'Coraline Official Trailer',
#  'Love on the Menu',
#  'Turn Left, Turn Right',
#  'Turn Left, Turn Right',
#  'Burke & Hare',
#  'Burma VJ',
#  'Burning Bright',
#  'Butter',
#  'The Perfect Christmas Present',
#  'Population Boom',
#  'My Christmas Prince',
#  'Bye Bye Love',
#  'Bye Bye Blackbird',
#  'Bye Bye Birdie',
#  'Bye Bye Birdie',
#  'Bye Bye Bluebird',
#  'The Chinese Feast',
#  'Béatrice Thiriet',
#  'Stage Door',
#  'The Truth About Jane and Sam',
#  'Sound of Christmas',
#  'Untitled Deadpool film',
#  'The Longest Nite',
#  'Naked Killer',
#  'C.H.U.D.',
#  'C.I.D.',
#  'C.R.A.Z.Y.',
#  'The Super',
#  "Mooby's",
#  'Oleg Kapanets',
#  'Notes for My Son',
#  'Toshinori Oda',
#  'CSNY/Déjà Vu',
#  'Ram Lee',
#  'Cash',
#  'Cash',
#  'Nightbreed',
#  'Kaos',
#  'Cadillac Man',
#  'Caged',
#  'Caged',
#  'Caged',
#  'Cairo Time',
#  'Corinne Dufour',
#  'Daisy Diamond',
#  'Dario',
#  'The Baytown Outlaws',
#  'Calexico',
#  'The Man from the Alamo',
#  'Fade to Black',
#  'Dr. Carl Mortner',
#  'I Hate Luv Storys',
#  'Elena',
#  'Elena',
#  'The Wedding Date',
#  'Revolution',
#  'Emile Leopold Locque',
#  'Heart Condition',
#  'White Sands',
#  'K-9',
#  'The Cave',
#  'The Cave',
#  'Women in Temptation',
#  'Jonas Brothers: The 3D Concert Experience',
#  'Justice, My Foot!',
#  'Gabriel Migliori',
#  'Gareth Mallory',
#  'General Medrano',
#  'George Michael: A Different Story',
#  'Gru',
#  'Bernie',
#  'Bernie',
#  'Bernie',
#  'Along the Navajo Trail',
#  'Amusement',
#  'The Public Eye',
#  "Susan's Plan",
#  'Alexander Geringas',
#  'Camouflage',
#  'Camp 14: Total Control Zone',
#  'Armadillo',
#  'Inherit the Wind',
#  'Inherit the Wind',
#  'Inherit the Wind',
#  'Tatie Danielle',
#  "Iron Man's armor (Marvel Cinematic Universe)",
#  'Jaime',
#  'Ricochet',
#  'Loverboy',
#  'Loverboy',
#  'Joe Butcher',
#  'Ian Mercer',
#  'Ian Mercer',
#  'José Miguel Wisnik',
#  'Empire of the Wolves',
#  'Kincade',
#  'Killer Tongue',
#  'Lupe Lamora',
#  "Leo D'Amato",
#  'Marco Antônio Guimarães',
#  'Markus Belby',
#  'The Dognapper',
#  'Mauro Senise',
#  'Canaris',
#  'May Day',
#  'Meet Wally Sparks',
#  'Chinese Fireball',
#  'Meu Passado Me Condena',
#  'Milton Krest',
#  'Minha Mãe é uma Peça',
#  'Miranda Frost',
#  'A Gift to Remember',
#  'Declaration of War',
#  'Hum Tum',
#  'Treehouse of Horror XXII',
#  'Cannibal',
#  'Cannibal',
#  'Welcome to the Jungle',
#  'Welcome to the Jungle',
#  'Welcome to the Jungle',
#  'Sleeping Beauty',
#  'Sleeping Beauty',
#  'Sleeping Beauty',
#  'Sleeping Beauty',
#  'Nam-Ek',
#  'Necros',
#  'Necrosis',
#  'Second Name',
#  'The Middle of the World',
#  'Suely in the Sky',
#  'The Man Who Copied',
#  'Time and the Wind',
#  "Can't Buy Me Love",
#  'Blue Eyes',
#  'Onaconda Farr',
#  'Oscar Francisco Nascimento',
#  'Artificial Paradises',
#  'Pola Ivanova',
#  'Captain Newman, M.D.',
#  'Captain Ron',
#  'Captive',
#  'Captive',
#  'Captive',
#  'Captivity',
#  'Wrestling Ernest Hemingway',
#  'Caravaggio',
#  'Caravaggio',
#  'Forbidden to Forbid',
#  'Richard White',
#  'Richard White',
#  'Under the Same Moon',
#  'Rosie Carver',
#  'Glenn Miller',
#  'Glenn Miller',
#  'Swallowtail',
#  'Mrs. Darbus',
#  'Somewhere Slow',
#  'Somos tão Jovens',
#  'How to Succeed in Business Without Really Trying',
#  'How to Succeed in Business Without Really Trying',
#  'Hip',
#  'Rich Texan',
#  'The Detainer',
#  'Totalmente Inocentes',
#  'Transcendence',
#  'Jedediah Leland',
#  'Jim W. Gettys',
#  'Tristan Thorn',
#  'Air Doll',
#  'VIPs',
#  'Vai que Dá Certo',
#  'Valentin Zukovsky',
#  'Pierre Volto',
#  'Vijay',
#  'Vijay',
#  'Christmas Crossfire',
#  'Christmas Getaway',
#  'We May Never Love Like This Again',
#  'Martial Arts of Shaolin',
#  'Sheriff J.W. Pepper',
#  'Kovář z Podlesí',
#  'Freak City',
#  'Three Comrades',
#  'Three Comrades',
#  'Belzebuth',
#  'Girls Just Want to Have Fun',
#  'Girls Just Want to Have Fun',
#  'Girls Just Want to Have Fun',
#  'Christmas with the Darlings',
#  'Day of the Comet',
#  "Carla's Song",
#  'All or Nothing',
#  'An Invisible Sign',
#  "Debbie Macomber's Dashing Through the Snow",
#  'Suddenly',
#  'Suddenly',
#  'Suddenly',
#  'Better Off Dead',
#  'Magical Christmas Ornaments',
#  'Perhaps Love',
#  'The Message',
#  'Avalon',
#  'Avalon',
#  'Avalon',
#  'Babylon Disease',
#  'Slovenian Film Centre',
#  'Carlo Siliotto',
#  'Braguinha',
#  'Nada Sōsō',
#  'Nada Sōsō',
#  'The Man Who Would Be King',
#  'The Man Who Would Be King',
#  'Taare Zameen Par',
#  'The Bench',
#  'Hail, Freedonia!',
#  'Lightyear',
#  'Departures',
#  'The Second Awakening of Christa Klages',
#  'La partition sonore et musicale de Dunkerque (C. Nolan, 2017). Une expérience sensorielle inédite',
#  'Blitzkriegs',
#  'Globo Gym Purple Cobras',
#  'Kamikazes',
#  "Kate Veach's house",
#  "Peter La Fleur's house",
#  'Veronika Schwarczová',
#  'Jaroslav Bouček',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Red Apple cigarettes',
#  'Jan Maxa',
#  'New York Doll',
#  'Casa de los Babys',
#  'Northern Lights of Christmas',
#  'Coda',
#  'Du är den ende – Music from "Tommy" a film by Tarik Saleh',
#  'Still Reigning',
#  'Devil in the Flesh 2',
#  'Dani Ardor',
#  'One Christmas Eve',
#  'ohmu',
#  'Stakeout',
#  'Stakeout',
#  'Rufus',
#  'Rufus',
#  'Rufus',
#  'Rufus',
#  'Black Rain',
#  'Cass',
#  'Casshern',
#  'A Man Comes Home',
#  'Christmas at Grand Valley',
#  'The Second Star to the Right',
#  'The Visitor',
#  'Merry Matrimony',
#  'Becky',
#  'Becky',
#  'Becky',
#  'Becky',
#  'Kim Yong',
#  'Knuckledust',
#  'Secret Magic Control Agency',
#  'Spy Game',
#  'Shaak Ti',
#  'High School Musical: The Concert',
#  'Castle Freak',
#  'This Means War',
#  'Undercover Kitty',
#  'The Last Metro',
#  'Freud Leaving Home',
#  'Showdown in Little Tokyo',
#  'Divine Secrets of the Ya-Ya Sisterhood',
#  'Divine Secrets of the Ya-Ya Sisterhood',
#  'Cat Run',
#  'Kumiko',
#  'Chozen Toguchi',
#  'Venator-class star destroyer',
#  'Immortals',
#  'Catchfire',
#  'Catch a Fire',
#  'Happythankyoumoreplease',
#  'Caterpillar',
#  'Caterpillar',
#  'The Graveyard',
#  'Existenz',
#  'Joe Gardner',
#  'Cutthroat Island',
#  'Caught',
#  'Caught',
#  'Caveman',
#  'DearS',
#  'Pacific Rim: The Black',
#  "New Year's Eve",
#  'Bianca',
#  'Bianca',
#  'Ninja Scroll',
#  'The Keys to the House',
#  'Harbinger',
#  'Celine Rattray',
#  'Kee Nang',
#  'I Wish',
#  'IMurders',
#  'In Your Veins',
#  'Ant-Man and the Wasp: Quantumania',
#  'Villain',
#  'Jackass 2.5',
#  'I Miss You',
#  'Central Station',
#  'The Great Magician',
#  'Pinocchio',
#  'Pinocchio',
#  'Pinocchio',
#  'Pinocchio',
#  'Pinocchio',
#  'Pinocchio',
#  'Pinocchio',
#  'Pinocchio',
#  'Pinocchio',
#  'Pinocchio',
#  'Pinocchio',
#  'The Conquest',
#  'The Conquest',
#  "I Just Didn't Do It",
#  'Shed No Tears',
#  'Lak Sivrak',
#  'A Ghost of a Chance',
#  'Kamisama no Karute',
#  'The Perfect Game',
#  'Carmen',
#  'Carmen',
#  'Carmen',
#  'Carmen',
#  'Carmen',
#  'Carmen',
#  'How did we get AIDS?',
#  'Newsies',
#  'Kansas City Confidential',
#  'The Conviction',
#  'Giovanni Korporaal',
#  'Anxiety',
#  'A Lady Without Passport',
#  'Fire with Fire',
#  'Fire with Fire',
#  'Fire with Fire',
#  "Just Another Pandora's Box",
#  'The Glass Menagerie',
#  'The Ear',
#  'The Big Bang',
#  'Persona non grata',
#  'Hara-Kiri: Death of a Samurai',
#  'Gente di Roma',
#  'Vanilla and Chocolate',
#  'Chaahat',
#  'The Consequences of Love',
#  'The Bankers of God: The Calvi Affair',
#  'Sadako 3D',
#  "Lorenzo's Oil",
#  'Waltz for Monica',
#  'Jeepers Creepers: Reborn',
#  'Kueki Ressha',
#  "Adam's Rib",
#  'Janie Jones',
#  'Chal Mere Bhai',
#  'Na Wewe',
#  'Beyond Outrage',
#  'Keep the Lights On',
#  'Volcano',
#  'Volcano',
#  'Volcano',
#  'Rethinking Progress',
#  'Like Someone in Love',
#  'Needle',
#  'Needle',
#  'Needle',
#  'Eddie and the Cruisers',
#  'Saimir',
#  'Zett Jukassa',
#  'Blue Spring',
#  'Jackpot',
#  'Jackpot',
#  'Jackpot',
#  'Chalte Chalte',
#  'The Good Doctor',
#  'ATM',
#  'Chamatkar',
#  'Chameli',
#  "The Time Will Come (Progress Studies Humans' Behavior)",
#  'Original',
#  'Burglars of Baghdad Castle',
#  'A Prophet',
#  'Seaspiracy',
#  'Chandani - The daughter of the elephant whisperer',
#  'Chandni Chowk to China',
#  'San Hill',
#  'Change My Life',
#  'Changing Times',
#  'To Hell and Back: The Kane Hodder Story',
#  'The Singer',
#  'Love Songs',
#  'Chaos',
#  'Chaos',
#  'Chaos',
#  'Chaos',
#  'Chaos',
#  'Felucia',
#  'Jürgen Knieper',
#  'Charade',
#  'Charade',
#  'Old Town Road (remix)',
#  'The Defiant Ones',
#  'The Weight',
#  'Ponda Baba',
#  'Profetia',
#  'Jingle All the Way',
#  'Death Hunt',
#  "The Great Rock 'n' Roll Swindle",
#  "The Great Rock 'n' Roll Swindle",
#  'Underground',
#  'Underground',
#  'Underground',
#  'hyperspace',
#  'Songs from The Little Mermaid II – Return to the Sea & More!',
#  'La Sirenita II – Regreso al mar y algo más',
#  'La Petite Sirène – Version française originale – Chansons et musique du Film',
#  "Chansons de La Petite Sirène et La Petite Sirène 2 – Retour à L'ocean",
#  "Dante's Inferno: An Animated Epic",
#  'Nothing to Lose',
#  'Nothing to Lose',
#  'Grunt',
#  'Straight to Hell',
#  'La Sirenita – Banda Sonora en Castellano',
#  'Karai',
#  'Karai',
#  'Karai',
#  'Karai',
#  'Karai',
#  'The Hidden Blade',
#  'Lower Elements Police – Reconnaissance',
#  "Sullivan's Travels",
#  'Charles Previn',
#  'Jackass 3D',
#  'Linda Linda Linda',
#  'Mel Jarnson',
#  'Multiple Sexualities, Multiple Identities LGBT Community and Indian Cinema: An Interface',
#  "Chloé Zhao's Oscar Win: Moment or Movement?",
#  'Happy Together',
#  'Happy Together',
#  'Happy Together',
#  'His Girl Friday',
#  'The Land Before Time',
#  'The Land Before Time',
#  'The Land Before Time',
#  'The Land Before Time',
#  'Simon & Malou',
#  'Toronto Star',
#  'My Best Friend Is a Vampire',
#  'Grizzly Man',
#  'Charly',
#  'Visible Secret',
#  'Casper and Emma on Safari',
#  'Fogell',
#  'Chasers',
#  'Carmen Beato',
#  'Blindspotting',
#  'Blindspotting',
#  'Veer-Zaara',
#  "Hell's Angels",
#  'Cloudboy',
#  'Jazz',
#  'Cheaters',
#  'Lies and Fat Girls',
#  'The Craigslist Killer',
#  'A Classic Horror Story',
#  'Star Trek: The Magazine Volume 1, Issue 4',
#  'Pure',
#  'Pure',
#  'Break Through!',
#  'Invincible',
#  'Invincible',
#  'Invincible',
#  'Star Trek: The Art of John Eaves',
#  'Cherry 2000',
#  "God Forgives... I Don't!",
#  'O-Ren Ishii',
#  'Keane',
#  'Love and Rage',
#  'Cheyenne Autumn',
#  'Alfred Hitchcock – Vertigo',
#  'Paul Krendler',
#  'Chicago Cab',
#  'Escape from Mogadishu',
#  'Lake Placid',
#  'Lake Placid',
#  'Lake Placid',
#  'Chico and Rita',
#  'Japón',
#  'Zero Day',
#  'April Story',
#  'Nico Fidenco',
#  'Martina Cariddi',
#  'Hostage: Missing Celebrity',
#  'North',
#  'Children Who Chase Lost Voices',
#  'Tomme tønner',
#  'Aglyamov Khairislam Aglyamovich',
#  'The Chef, the Actor, the Scoundrel',
#  'Hong Kong Confidential',
#  'Comet in Moominland',
#  'Comet in Moominland',
#  'Die unendliche Geschichte – Das Album',
#  'Quentin Smith',
#  'Atli Oskar Fjalarsson',
#  'Dear Friends',
#  'Andrew Duncan',
#  'Strings',
#  'Once Upon a Time in Hollywood',
#  'Once Upon a Time in Hollywood',
#  'Tenshi no Koi',
#  'Countdown to Zero',
#  'Evey Hammond',
#  'Toshiyuki Watanabe',
#  'Gia',
#  'Gia',
#  'Vitaly',
#  'Stefano',
#  'Charles Mingus',
#  'The Founding of a Party',
#  'Descendants: The Royal Wedding',
#  'Chisum',
#  'Fabio Laguna',
#  'RoboCop: Rogue City',
#  'Momaw Nadon',
#  'Ghostbusters – Original Soundtrack Album',
#  'Love Actually – The Original Soundtrack',
#  'The Stool Pigeon',
#  'Esmerelda Villalobos',
#  'Choke',
#  'Choke',
#  'Choking Hazard',
#  'Beast Stalker',
#  'Ugetsu',
#  'Swing Kids',
#  'Gallipoli',
#  'Antitrust',
#  'The Truce',
#  'The Truce',
#  'Chris Walden',
#  'Street Angel',
#  'Undisputed II: Last Man Standing',
#  'The Magician',
#  'The Magician',
#  'Christian Chevallier',
#  'Truck Turner',
#  'Sky Fighters',
#  'Cohen and Tate',
#  "Christina's House",
#  'Johnny Handsome',
#  'Men at Work',
#  'Witchery',
#  'Magic Kitchen',
#  'The 5th Quarter',
#  'Díra u Hanušovic',
#  'I, Olga Hepnarová',
#  'Big Eyes',
#  'Pee Mak',
#  'An Earthly Paradise For The Eyes',
#  'Ip Man: The Final Fight',
#  "Let's Get Lost",
#  "Let's Get Lost",
#  'Badges of Fury',
#  'Christopher Tin',
#  'The Bait',
#  "Don't Go Breaking My Heart",
#  'Akame 48 Waterfalls',
#  'Christ Stopped at Eboli',
#  'Kagero-za',
#  'A True Mob Story',
#  'Shanghai Grand',
#  'Chromophobia',
#  'Lee Rock',
#  'Chrysalis',
#  'Chrysalis',
#  'Chrysalis',
#  'The House of Smiles',
#  'Monty Montgomery',
#  'Woman Sesame Oil Maker',
#  'Unknown Chaplin',
#  'KITT',
#  'Blood of the Innocent',
#  'Vlad',
#  'Sophie',
#  'Escape',
#  'Escape',
#  'Escape',
#  'Concrete Blondes',
#  'A Few Good Men',
#  'A Few Good Men',
#  'Born to Kill',
#  'Min and Bill',
#  'Return to Horror High',
#  'Big Trouble',
#  'Big Trouble',
#  'Flying Swords of Dragon Gate',
#  'Skagerrak',
#  'Children of the Century',
#  'Moshidora',
#  'Moshidora',
#  'Kikujiro',
#  'Marked for Death',
#  'Evening',
#  'Showtime',
#  'Showtime',
#  'Holiday in Handcuffs',
#  'Happy',
#  'Happy',
#  'Circus',
#  'Circus World',
#  'Black Snow',
#  'The Adventurers',
#  'Howling III',
#  'Mulholland Falls',
#  'RKO 281',
#  'Citizen X',
#  'The Richest Duck in the World',
#  'The Billionaire of Dismal Downs',
#  'Double Tap',
#  'Almost Human',
#  'Almost Human',
#  'Big Fish & Begonia',
#  'The Rooftop',
#  'City of Ghosts',
#  'Echo Base',
#  'Re-Animated',
#  'The Tall Blond Man with One Black Shoe',
#  'The Empire-Builder from Calisota',
#  'Yuva',
#  'Battle of Warsaw 1920',
#  'Suicide Room',
#  'Little Moscow',
#  'Rope',
#  'Rope',
#  'Wojciech Jerzy Has',
#  'Tiny Times',
#  'Foggy Nelson',
#  'The Malay Chronicles: Bloodlines',
#  'Kokoda',
#  'Indie Game: The Movie',
#  'Vishwanatha Nayakudu',
#  'Go Go Tales',
#  'Hello Mary Lou: Prom Night II',
#  'Trekkies',
#  'Claus Boje',
#  'Do Anjaane',
#  'Cleaner',
#  'Mausam',
#  'Mausam',
#  'Insaaf Ka Tarazu',
#  'Life Without Principle',
#  'Venghai',
#  'Veppam',
#  'Cleopatra',
#  'Cleopatra',
#  'Cleopatra',
#  'Cleopatra',
#  'Cleopatra',
#  'Macao',
#  'Clive Langer',
#  'Ken Masters',
#  'Clockwise',
#  'Mashaal',
#  'Closet Land',
#  'Closing the Ring',
#  'Club Dread',
#  'Club Paradise',
#  'Caitiaan',
#  'A Thousand Words',
#  'Flickering Lights',
#  'Rufus Shinra',
#  'Coach Carter',
#  'Chasing Papi',
#  'Ghatak: Lethal',
#  'Code 46',
#  'Code Name: The Cleaner',
#  'Dev',
#  'Dev',
#  'Ba’ku',
#  'Nights on the Road',
#  'The Street with No Name',
#  'Nobel Son',
#  'When the Sea Rises',
#  'Yuppi du',
#  'Le Marginal',
#  'Coldblooded',
#  'Cold Fever',
#  'Cold Creek Manor',
#  'Cold Prey 2',
#  'As the Light Goes Out',
#  'Mixmaster',
#  'Jonah Who Lived in the Whale',
#  'College Road Trip',
#  'Sherlock Holmes',
#  'Sherlock Holmes',
#  'Sherlock Holmes',
#  'Sherlock Holmes',
#  'Tere Naam',
#  'Dr. Alexander Isaacs',
#  'Fled',
#  'The Five Pennies',
#  'Proton pack',
#  'Off Beat',
#  'Color of Night',
#  'Colors',
#  'Babes in Toyland',
#  'Babes in Toyland',
#  'Babes in Toyland',
#  'Babes in Toyland',
#  'High Crimes',
#  'Sunshine Cleaning',
#  'Hellsinki',
#  "I Don't Speak English",
#  'Them',
#  'Rigor Mortis',
#  'The Dancer Upstairs',
#  'The Dancer Upstairs',
#  'Curiosity Kills the Cat',
#  'Comandante',
#  "I'll Be There",
#  'The Island',
#  'The Island',
#  'The Island',
#  'The Island',
#  'The Island',
#  'Tender Mercies',
#  'Nouvelle Vague',
#  'The Chronicle of Anna Magdalena Bach',
#  'Career Opportunities',
#  'Naayika',
#  'Overnight Delivery',
#  'Cougar Club',
#  'The Cruelest Day',
#  'The Mourning Forest',
#  'A No-Hit No-Run Summer',
#  'The Liberator',
#  'Radio Rebel',
#  'Radio Rebel',
#  'Foolish Wives',
#  'Something New',
#  'Down to Earth',
#  'The Woman Next Door',
#  'Rachel Getting Married',
#  "The Emperor's New Clothes",
#  "The Emperor's New Clothes",
#  'Dawson Isla 10',
#  'The Hireling',
#  'Ronda nocturna',
#  'The Four-Faced Liar',
#  'Garm Wars: The Last Druid',
#  'Dead Space: Downfall',
#  'The Body',
#  'The Body',
#  'The Body',
#  'The Body',
#  'Forgotten',
#  'Saratoga Trunk',
#  'The War of the Roses',
#  'The War of the Roses',
#  'Nathan Birnbaum',
#  'Nameless Gangster',
#  'Definitely, Maybe',
#  'Tom Thumb',
#  'Tom Thumb',
#  'Tom Thumb',
#  'Horst',
#  'Soul Men',
#  'Nidra',
#  'Mogambo',
#  'Denis',
#  'Born Romantic',
#  'Me and the Kid',
#  'Narasaki',
#  'NECK',
#  'The Number 23',
#  'Live Free or Die',
#  'Evita – The Complete Motion Picture Music Soundtrack',
#  'Hidden Agenda',
#  'Hidden Agenda',
#  'Brotherhood of the Wolf',
#  'Prime',
#  'XL Recordings',
#  'Double Zero',
#  'Hide and Seek',
#  'Hide and Seek',
#  'Horror Stories',
#  'Condorman',
#  'Frankenhooker',
#  'Six Days Seven Nights',
#  'Tightrope',
#  'USS Titan',
#  'Bad Cat',
#  'Louise Hires a Contract Killer',
#  'The Day of the Dolphin',
#  'The Day of the Dolphin',
#  'Hana-bi',
#  'Kill Theory',
#  'Le cousin',
#  'The Geisha House',
#  'Replay',
#  'Replay',
#  'Wonderland',
#  'Wonderland',
#  'Wonderland',
#  'Wonderland',
#  'Wonderland',
#  'Wonderland',
#  'Connie and Carla',
#  "Connors' War",
#  'Conquest',
#  'Casualties of War',
#  'Husbands in Goa',
#  'The Colonel',
#  'Crane',
#  'Crane',
#  'Dark City',
#  "God Is Great and I'm Not",
#  'Trouble with the Curve',
#  'My Gal Sal',
#  'True Romance',
#  'Queen to Play',
#  "It's Not Me, I Swear!",
#  'Colour Me Kubrick',
#  'Year One',
#  'Daybreakers',
#  'The Black Orchid',
#  'Hall Pass',
#  'Crazy Heart',
#  'The Girl in the Park',
#  'I Love You Phillip Morris',
#  'Contraband',
#  'Eloise Midgen',
#  'Control',
#  'Control',
#  'Alien Apocalypse',
#  'Make the Yuletide Gay',
#  'Barnyard',
#  'Push',
#  'Push',
#  'The Convent',
#  'The Convent',
#  'The Milk of Sorrow',
#  'Conversations with Other Women',
#  'Tangled',
#  'Tangled',
#  'Tangled',
#  'A Little Thing Called Murder',
#  'Norbit',
#  'Cookie',
#  'Cookie',
#  'Cooking History',
#  "Goya's Ghosts",
#  'East of Eden',
#  'East of Eden',
#  'The Double Life of Véronique',
#  'The Skin I Live In',
#  'Of Gods and Men',
#  'Come and See',
#  'Saidoweizu',
#  'The 9th Company',
#  'Elizabethtown',
#  'The Rite',
#  'Far from Heaven',
#  'Olivia in Concert',
#  'Mammuth',
#  'The Merry Widow',
#  'The Merry Widow',
#  'How the Toys Saved Christmas',
#  "The Slammin' Salmon",
#  'Suddenly, Last Summer',
#  'Suddenly, Last Summer',
#  'P.S. Your Cat Is Dead',
#  'P.S. Your Cat Is Dead',
#  'The Hot Chick',
#  'Showdown in Seoul',
#  'Cops & Robbersons',
#  'Rollover',
#  'Capturing Dad',
#  'Warlock: The Armageddon',
#  'The NeverEnding Story – Original Motion Picture Soundtrack',
#  'Demons of War',
#  'klingon Bird of Prey',
#  'Corinne Marrinan',
#  'Green Street',
#  'Sri Rama Rajyam',
#  'The Wedding Singer',
#  'Red River',
#  'Three Lives and Only One Death',
#  'Green Snake',
#  'Freaks',
#  'Hogwarts defenders',
#  'Napoleon Dynamite',
#  'Haunted Mansion Holiday',
#  'Most',
#  'Borg cube',
#  'Cornelius Schwehr',
#  'Under the Hawthorn Tree',
#  'Oskar & Josefine',
#  'The Whisperers',
#  'The Sweetest Thing',
#  'The Profession of Arms',
#  'Strays',
#  'Ed',
#  'Ed',
#  'Magadheera',
#  'Vanishing Point',
#  'Vanishing Point',
#  'Little Maestra',
#  'Rudolf and Ippaiattena',
#  'Invisible Target',
#  'Corrina, Corrina',
#  'The Corruptor',
#  'A Chinese Ghost Story',
#  'A Chinese Ghost Story',
#  'For Keeps',
#  'Boo',
#  'Ladyhawke',
#  'Tatsuya Kushida',
#  'Contre-enquête',
#  'Teenage Mutant Ninja Turtles: Music from the Motion Picture',
#  'Xavier Marchand',
#  'Runaway Train',
#  'J. Edgar',
#  ...]

# %%
df = df_ent[df_ent['label']=="a"]

# %%
len(df)
# Out:
# 0

# %%
df_ent
# Out:
#                                               uri  \
# 0         http://www.wikidata.org/entity/Q1000825
# 1       http://www.wikidata.org/entity/Q100151796
# 2         http://www.wikidata.org/entity/Q1001777
# 3         http://www.wikidata.org/entity/Q1001943
# 4         http://www.wikidata.org/entity/Q1001994
# ...                                           ...
# 157754     http://www.wikidata.org/entity/Q723685
# 157755      http://www.wikidata.org/entity/Q11424
# 157756       http://www.wikidata.org/entity/Q1860
# 157757         http://www.wikidata.org/entity/Q30
# 157758      http://www.wikidata.org/entity/Q33999
#
#                                                     label
# 0                                                Jan Dara
# 1                 Elektra – Original Motion Picture Score
# 2                                          Moondram Pirai
# 3       Buffalo Bill and the Indians, or Sitting Bull'...
# 4                                           Buffalo Girls
# ...                                                   ...
# 157754                                    video on demand
# 157755                                               film
# 157756                                            English
# 157757                           United States of America
# 157758                                              actor
#
# [157759 rows x 2 columns]
